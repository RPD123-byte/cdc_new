# %%
import requests
import pandas as pd
from urllib.parse import urlencode
import time

def get_data(endpoint, params=None):
    base_url = "http://tour-pedia.org/api"
    url = f"{base_url}/{endpoint}"
    if params:
        url += "?" + urlencode(params)
    
    print(f"Requesting: {url}")
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

def fetch_all_data():
    locations = ["Amsterdam", "Barcelona", "Berlin", "Dubai", "London", "Paris", "Rome", "Tuscany"]
    categories = ["accommodation", "attraction", "poi", "restaurant"]
    
    all_places = []
    all_reviews = []
    
    for location in locations:
        for category in categories:
            print(f"Fetching {category} in {location}")
            
            # Fetch places
            places = get_data("getPlaces", {"location": location, "category": category})
            if places:
                all_places.extend(places)
                
                # Fetch reviews for each place
                for place in places:
                    reviews = get_data("getReviews", {"location": location, "category": category, "placeId": place['id']})
                    if reviews:
                        for review in reviews:
                            review['place_id'] = place['id']  # Add place_id to the review
                        all_reviews.extend(reviews)
                    
    # Create DataFrames
    places_df = pd.DataFrame(all_places)
    reviews_df = pd.DataFrame(all_reviews)
    
    return places_df, reviews_df

# Fetch the data
places_df, reviews_df = fetch_all_data()

# Display info about the DataFrames
print("\nPlaces DataFrame:")
print(places_df.info())
print("\nReviews DataFrame:")
print(reviews_df.info())

# Save to CSV (optional)
places_df.to_csv('places_data.csv', index=False)
reviews_df.to_csv('reviews_data.csv', index=False)

print("\nData fetching complete. DataFrames created and saved to CSV files.")
# Out:
# Fetching accommodation in Amsterdam
# Requesting: http://tour-pedia.org/api/getPlaces?location=Amsterdam&category=accommodation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/rithvikprakki/CDC_2024/get_data.ipynb Cell 1 line 5
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=51'>52</a>     return places_df, reviews_df
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=53'>54</a> # Fetch the data
# ---> <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=54'>55</a> places_df, reviews_df = fetch_all_data()
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=56'>57</a> # Display info about the DataFrames
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a> print("\nPlaces DataFrame:")
#
# /Users/rithvikprakki/CDC_2024/get_data.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> print(f"Fetching {category} in {location}")
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a> # Fetch places
# ---> <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> places = get_data("getPlaces", {"location": location, "category": category})
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a> if places:
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     all_places.extend(places)
#
# /Users/rithvikprakki/CDC_2024/get_data.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     url += "?" + urlencode(params)
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> print(f"Requesting: {url}")
# ---> <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> response = requests.get(url)
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> if response.status_code == 200:
#      <a href='vscode-notebook-cell:/Users/rithvikprakki/CDC_2024/get_data.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a>     return response.json()
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/urllib3/response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/urllib3/response.py:1209, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1207 if self.chunk_left == 0:
#    1208     break
# -> 1209 chunk = self._handle_chunk(amt)
#    1210 decoded = self._decode(
#    1211     chunk, decode_content=decode_content, flush_decoder=False
#    1212 )
#    1213 if decoded:
#
# File ~/CDC_2024/cdc/lib/python3.12/site-packages/urllib3/response.py:1155, in HTTPResponse._handle_chunk(self, amt)
#    1153     returned_chunk = value
#    1154 else:  # amt > self.chunk_left
# -> 1155     returned_chunk = self._fp._safe_read(self.chunk_left)  # type: ignore[union-attr]
#    1156     self._fp._safe_read(2)  # type: ignore[union-attr] # Toss the CRLF at the end of the chunk.
#    1157     self.chunk_left = None
#
# File /opt/homebrew/Cellar/python@3.12/3.12.2_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File /opt/homebrew/Cellar/python@3.12/3.12.2_1/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
from urllib.parse import urlencode
import time

def get_data(endpoint, params=None):
    base_url = "http://tour-pedia.org/api"
    url = f"{base_url}/{endpoint}"
    if params:
        url += "?" + urlencode(params)
    
    print(f"Requesting: {url}")
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

def fetch_amsterdam_accommodations_with_reviews():
    params = {
        "location": "Amsterdam",
        "category": "accommodation"
    }
    
    accommodations = get_data("getPlaces", params)
    
    if not accommodations:
        print("Failed to retrieve accommodation data")
        return None

    print(f"Retrieved {len(accommodations)} accommodations in Amsterdam")
    
    for accommodation in accommodations:
        # Fetch reviews
        reviews = get_data("getReviewsByPlaceId", {"placeId": accommodation['id']})
        if reviews:
            accommodation['reviews_text'] = [review.get('text', '') for review in reviews]
        else:
            accommodation['reviews_text'] = []

        # Fetch details
        details = get_data("getPlaceDetails", {"id": accommodation['id']})
        if details:
            accommodation['details_text'] = details
        else:
            accommodation['details_text'] = {}

    return pd.DataFrame(accommodations)

# Fetch the data
accommodations_df = fetch_amsterdam_accommodations_with_reviews()

if accommodations_df is not None:
    # Display info about the DataFrame
    print("\nAccommodations DataFrame:")
    print(accommodations_df.info())

    # Display the first few rows
    print("\nFirst few rows of the DataFrame:")
    print(accommodations_df.head())

    # Save to CSV (optional)
    accommodations_df.to_csv('amsterdam_accommodations_with_reviews.csv', index=False)
    print("\nData saved to 'amsterdam_accommodations_with_reviews.csv'")

    # Basic statistics
    print("\nBasic statistics of numerical columns:")
    print(accommodations_df.describe())

    # Check for missing values
    print("\nMissing values in each column:")
    print(accommodations_df.isnull().sum())

    # Sample of reviews
    print("\nSample of reviews for the first accommodation:")
    if len(accommodations_df) > 0 and len(accommodations_df.iloc[0]['reviews_text']) > 0:
        print(accommodations_df.iloc[0]['reviews_text'][0])
    else:
        print("No reviews available for the first accommodation.")

    # Sample of details
    print("\nSample of details for the first accommodation:")
    if len(accommodations_df) > 0:
        print(accommodations_df.iloc[0]['details_text'])
    else:
        print("No details available for the first accommodation.")
else:
    print("No data to analyze")
# Out:
# Requesting: http://tour-pedia.org/api/getPlaces?location=Amsterdam&category=accommodation
# Retrieved 1393 accommodations in Amsterdam
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=223771
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=223771
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=223776
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=223776
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=223778
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=223778
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=223779
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32665
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32665
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32670
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32670
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32674
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32674
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32766
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32766
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32769
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32769
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32775
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32775
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32786
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32786
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32830
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32830
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32848
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32848
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32857
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32857
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32861
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32861
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32862
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32862
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32911
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32911
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32946
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32946
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32975
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32975
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32984
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32984
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32985
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32985
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33000
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33000
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33072
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33072
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33140
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33140
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33154
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33154
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33167
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33167
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33180
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33180
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33242
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33242
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33259
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33259
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33310
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33310
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33347
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33347
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33370
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33370
#
# Accommodations DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1393 non-null   int64
#  1   name          1393 non-null   object
#  2   address       1393 non-null   object
#  3   category      1393 non-null   object
#  4   location      1393 non-null   object
#  5   lat           1393 non-null   float64
#  6   lng           1393 non-null   float64
#  7   numReviews    506 non-null    float64
#  8   reviews       506 non-null    object
#  9   polarity      573 non-null    float64
#  10  details       1393 non-null   object
#  11  reviews_text  1393 non-null   object
#  12  details_text  1393 non-null   object
#  13  originalId    117 non-null    object
#  14  subCategory   117 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 163.4+ KB
# None
#
# First few rows of the DataFrame:
#        id                                    name  \
# 0  223771                          American Hotel
# 1  223776              Hotel Espresso City Center
# 2  223778                         Hotel Amsterdam
# 3  223779  Hampshire Boutique Hotel - Sebastian's
# 4  223793                                NL Hotel
#
#                                              address       category  \
# 0              Leidsekade 97, Amsterdam, Netherlands  accommodation
# 1                Overtoom 57, Amsterdam, Netherlands  accommodation
# 2               Damrak 93-94, Amsterdam, Netherlands  accommodation
# 3           Keizersgracht 15, Amsterdam, Netherlands  accommodation
# 4  Frans van Mierisstraat 34, Amsterdam, Netherlands  accommodation
#
#     location        lat       lng  numReviews  \
# 0  Amsterdam  52.363826  4.881369         5.0
# 1  Amsterdam  52.362864  4.876344         5.0
# 2  Amsterdam  52.373690  4.893623         NaN
# 3  Amsterdam  52.379109  4.889793         3.0
# 4  Amsterdam  52.354664  4.882476         NaN
#
#                                              reviews  polarity  \
# 0  http://tour-pedia.org/api/getReviewsByPlaceId?...       8.0
# 1  http://tour-pedia.org/api/getReviewsByPlaceId?...       0.0
# 2                                                NaN       NaN
# 3  http://tour-pedia.org/api/getReviewsByPlaceId?...       6.0
# 4                                                NaN       NaN
#
#                                              details  \
# 0  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 1  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 2  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 3  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 4  http://tour-pedia.org/api/getPlaceDetails?id=2...
#
#                                         reviews_text  \
# 0  [We went here for the sunday jazz brunch. The ...
# 1  [Rooms are nice and clean..hotel staff are ext...
# 2                                                 []
# 3  [My girlfriend and I had a lovely 4-night stay...
# 4                                                 []
#
#                                         details_text originalId subCategory
# 0  {'id': 223771, 'name': 'American Hotel', 'addr...        NaN         NaN
# 1  {'id': 223776, 'name': 'Hotel Espresso City Ce...        NaN         NaN
# 2  {'id': 223778, 'name': 'Hotel Amsterdam', 'add...        NaN         NaN
# 3  {'id': 223779, 'name': 'Hampshire Boutique Hot...        NaN         NaN
# 4  {'id': 223793, 'name': 'NL Hotel', 'address': ...        NaN         NaN
#
# Data saved to 'amsterdam_accommodations_with_reviews.csv'
#
# Basic statistics of numerical columns:
#                   id          lat          lng  numReviews    polarity
# count    1393.000000  1393.000000  1393.000000  506.000000  573.000000
# mean   203323.496770    52.367936     4.889867    8.994071    5.448517
# std    126788.464708     0.012790     0.025944   14.807075    3.326029
# min     31052.000000    52.323924     4.764862    1.000000    0.000000
# 25%    214947.000000    52.360702     4.880165    2.000000    3.000000
# 50%    224109.000000    52.368135     4.890959    4.000000    6.000000
# 75%    224457.000000    52.375771     4.899471    9.000000    8.000000
# max    541473.000000    52.421156     5.026116  121.000000   10.000000
#
# Missing values in each column:
# id                 0
# name               0
# address            0
# category           0
# location           0
# lat                0
# lng                0
# numReviews       887
# reviews          887
# polarity         820
# details            0
# reviews_text       0
# details_text       0
# originalId      1276
# subCategory     1276
# dtype: int64
#
# Sample of reviews for the first accommodation:
# We went here for the sunday jazz brunch. The art deco room where brunch is served is beautiful, the music is lovely and the seating very comfortable. The brunch is buffet style so the service is restricted to drinks really but it was fine. I felt that the food was not of the same quality as the surroundings, and therefore the €40 pp is not good value.
#
# Sample of details for the first accommodation:
# {'id': 223771, 'name': 'American Hotel', 'address': 'Leidsekade 97, Amsterdam, Netherlands', 'category': 'accommodation', 'location': 'Amsterdam', 'lat': 52.363826, 'lng': 4.881369, 'services': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None}, 'phone_number': '020 556 3000', 'international_phone_number': '+31 20 556 3000', 'website': 'http://www.hampshire-hotels.com/amsterdam-american-hotel-hampshire-eden', 'icon': 'http://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png', 'description': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None, 'unidentified': None}, 'external_urls': {'Foursquare': '', 'Facebook': '', 'GooglePlaces': 'https://plus.google.com/107504751032035756015/about?hl=en-US', 'Booking': {'en': 'http://www.booking.com/hotel/nl/american.en-gb.html', 'fr': 'http://www.booking.fr/hotel/nl/american.fr.html', 'it': 'http://www.booking.it/hotel/nl/american.it.html', 'es': 'http://www.booking.es/hotel/nl/american.es.html', 'de': 'http://www.booking.de/hotel/nl/american.de.html', 'nl': 'http://www.booking.nl/hotel/nl/american.nl.html'}}, 'statistics': {'Foursquare': {'checkinsCount': None, 'usersCount': None, 'tipCount': None, 'price': None, 'likes': None, 'hereNow': {'count': None, 'summary': None, 'groups': []}}, 'Facebook': {'checkins': None, 'talking_about_count': None, 'were_here_count': None, 'fan_count': None}}, 'numReviews': 5, 'reviews': ['533ecc7bae9eef521e5ecef4', '533ecc7bae9eef521e5ecef5', '533ecc7bae9eef521e5ecef6', '533ecc7bae9eef521e5ecef7', '533ecc7bae9eef521e5ecef8'], 'polarity': 8}

# %%
import requests
import pandas as pd
from urllib.parse import urlencode
import time
from concurrent.futures import ThreadPoolExecutor, as_completed  # Changed import
import sys

def get_data(endpoint, params=None):
    """
    Fetch data from the Tour-Pedia API.

    Args:
        endpoint (str): API endpoint to call.
        params (dict, optional): Query parameters for the API call.

    Returns:
        dict or list: Parsed JSON response from the API, or None if an error occurs.
    """
    base_url = "http://tour-pedia.org/api"
    url = f"{base_url}/{endpoint}"
    if params:
        url += "?" + urlencode(params)
    
    print(f"Requesting: {url}")
    try:
        response = requests.get(url, timeout=10)  # Added timeout for robustness
        response.raise_for_status()  # Raises HTTPError for bad responses
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

def process_accommodation(accommodation):
    """
    Process a single accommodation by fetching its reviews and details.

    Args:
        accommodation (dict): Accommodation data.

    Returns:
        dict: Updated accommodation data with reviews and details.
    """
    # Fetch reviews
    reviews = get_data("getReviewsByPlaceId", {"placeId": accommodation.get('id')})
    if reviews:
        accommodation['reviews_text'] = [review.get('text', '') for review in reviews]
    else:
        accommodation['reviews_text'] = []

    # Fetch details
    details = get_data("getPlaceDetails", {"id": accommodation.get('id')})
    if details:
        accommodation['details_text'] = details
    else:
        accommodation['details_text'] = {}

    time.sleep(1)  # Be nice to the API
    return accommodation

def fetch_amsterdam_accommodations_with_reviews():
    """
    Fetch accommodations in Amsterdam and enrich them with reviews and details.

    Returns:
        pd.DataFrame or None: DataFrame containing enriched accommodation data, or None if failed.
    """
    params = {
        "location": "Amsterdam",
        "category": "accommodation"
    }
    
    accommodations = get_data("getPlaces", params)
    
    if not accommodations:
        print("Failed to retrieve accommodation data")
        return None

    print(f"Retrieved {len(accommodations)} accommodations in Amsterdam")
    
    # Use ThreadPoolExecutor for parallel processing
    with ThreadPoolExecutor(max_workers=8) as executor:
        # Submit all tasks to the executor
        futures = {executor.submit(process_accommodation, accommodation): accommodation for accommodation in accommodations}
        
        processed_accommodations = []
        for future in as_completed(futures):
            try:
                result = future.result()
                if result:
                    processed_accommodations.append(result)
            except Exception as e:
                accommodation = futures[future]
                print(f"Error processing accommodation ID {accommodation.get('id')}: {e}", file=sys.stderr)
    
    return pd.DataFrame(processed_accommodations)

def main():
    """
    Main function to execute the data fetching and processing.
    """
    accommodations_df = fetch_amsterdam_accommodations_with_reviews()

    if accommodations_df is not None and not accommodations_df.empty:
        # Display info about the DataFrame
        print("\nAccommodations DataFrame:")
        print(accommodations_df.info())

        # Display the first few rows
        print("\nFirst few rows of the DataFrame:")
        print(accommodations_df.head())

        # Save to CSV
        accommodations_df.to_csv('amsterdam_accommodations_with_reviews.csv', index=False)
        print("\nData saved to 'amsterdam_accommodations_with_reviews.csv'")

        # Basic statistics
        print("\nBasic statistics of numerical columns:")
        print(accommodations_df.describe())

        # Check for missing values
        print("\nMissing values in each column:")
        print(accommodations_df.isnull().sum())

        # Sample of reviews
        print("\nSample of reviews for the first accommodation:")
        if len(accommodations_df) > 0 and accommodations_df.iloc[0].get('reviews_text'):
            print(accommodations_df.iloc[0]['reviews_text'][0])
        else:
            print("No reviews available for the first accommodation.")

        # Sample of details
        print("\nSample of details for the first accommodation:")
        if len(accommodations_df) > 0 and accommodations_df.iloc[0].get('details_text'):
            print(accommodations_df.iloc[0]['details_text'])
        else:
            print("No details available for the first accommodation.")
    else:
        print("No data to analyze")

if __name__ == '__main__':
    main()
# Out:
# Requesting: http://tour-pedia.org/api/getPlaces?location=Amsterdam&category=accommodation
# Retrieved 1393 accommodations in Amsterdam
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32068
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32127
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32155
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32228
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32236
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32236
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32255
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32303
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32341
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32255
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32353
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32358
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32359
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32421
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32303
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32341
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32353
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32358
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32359
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32474
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32421
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32474
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32481
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32553
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32481
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32560
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32564
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32657
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32659
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32553
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32662
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32560
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32564
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32659
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32657
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32665
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32662
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32665
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32670
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32674
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32766
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32670
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32769
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32775
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32786
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32674
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32830
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32766
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32769
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32775
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32786
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32830
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32848
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32848
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32857
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32861
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32857
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32862
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32911
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32946
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32975
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32984
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32861
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32911
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32862
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32975
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32946
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32984
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=32985
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=32985
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33000
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33072
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33140Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33154
#
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33000
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33167
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33180
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33242
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33072
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33140
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33154
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33167
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33180
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33242
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33259
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33259
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33310
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33347
# Requesting: http://tour-pedia.org/api/getReviewsByPlaceId?placeId=33370
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33310
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33347
# Requesting: http://tour-pedia.org/api/getPlaceDetails?id=33370
#
# Accommodations DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1393 non-null   int64
#  1   name          1393 non-null   object
#  2   address       1393 non-null   object
#  3   category      1393 non-null   object
#  4   location      1393 non-null   object
#  5   lat           1393 non-null   float64
#  6   lng           1393 non-null   float64
#  7   numReviews    506 non-null    float64
#  8   reviews       506 non-null    object
#  9   polarity      573 non-null    float64
#  10  details       1393 non-null   object
#  11  reviews_text  1393 non-null   object
#  12  details_text  1393 non-null   object
#  13  originalId    117 non-null    object
#  14  subCategory   117 non-null    object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 163.4+ KB
# None
#
# First few rows of the DataFrame:
#        id                                    name  \
# 0  223829  Amsterdam Bed and Breakfast CityCenter
# 1  223835                  FALCON PLAZA AMSTERDAM
# 2  223818                              BLUE TOWER
# 3  223771                          American Hotel
# 4  223793                                NL Hotel
#
#                                              address       category  \
# 0       Sint Jacobsstraat 21, Amsterdam, Netherlands  accommodation
# 1   Valkenburgerstraat 72-74, Amsterdam, Netherlands  accommodation
# 2        Leeuwendalersweg 21, Amsterdam, Netherlands  accommodation
# 3              Leidsekade 97, Amsterdam, Netherlands  accommodation
# 4  Frans van Mierisstraat 34, Amsterdam, Netherlands  accommodation
#
#     location        lat       lng  numReviews  \
# 0  Amsterdam  52.376568  4.894706         5.0
# 1  Amsterdam  52.369949  4.907378         4.0
# 2  Amsterdam  52.379318  4.845886         5.0
# 3  Amsterdam  52.363826  4.881369         5.0
# 4  Amsterdam  52.354664  4.882476         NaN
#
#                                              reviews  polarity  \
# 0  http://tour-pedia.org/api/getReviewsByPlaceId?...      10.0
# 1  http://tour-pedia.org/api/getReviewsByPlaceId?...       3.0
# 2  http://tour-pedia.org/api/getReviewsByPlaceId?...       3.0
# 3  http://tour-pedia.org/api/getReviewsByPlaceId?...       8.0
# 4                                                NaN       NaN
#
#                                              details  \
# 0  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 1  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 2  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 3  http://tour-pedia.org/api/getPlaceDetails?id=2...
# 4  http://tour-pedia.org/api/getPlaceDetails?id=2...
#
#                                         reviews_text  \
# 0  [If anybody is searching for a great place to ...
# 1  [just ok place, some rooms can be very small, ...
# 2  [Value for money, Nos alojamos en este hotel e...
# 3  [We went here for the sunday jazz brunch. The ...
# 4                                                 []
#
#                                         details_text originalId subCategory
# 0  {'id': 223829, 'name': 'Amsterdam Bed and Brea...        NaN         NaN
# 1  {'id': 223835, 'name': 'FALCON PLAZA AMSTERDAM...        NaN         NaN
# 2  {'id': 223818, 'name': 'BLUE TOWER', 'address'...        NaN         NaN
# 3  {'id': 223771, 'name': 'American Hotel', 'addr...        NaN         NaN
# 4  {'id': 223793, 'name': 'NL Hotel', 'address': ...        NaN         NaN
#
# Data saved to 'amsterdam_accommodations_with_reviews.csv'
#
# Basic statistics of numerical columns:
#                   id          lat          lng  numReviews    polarity
# count    1393.000000  1393.000000  1393.000000  506.000000  573.000000
# mean   203323.496770    52.367936     4.889867    8.994071    5.448517
# std    126788.464708     0.012790     0.025944   14.807075    3.326029
# min     31052.000000    52.323924     4.764862    1.000000    0.000000
# 25%    214947.000000    52.360702     4.880165    2.000000    3.000000
# 50%    224109.000000    52.368135     4.890959    4.000000    6.000000
# 75%    224457.000000    52.375771     4.899471    9.000000    8.000000
# max    541473.000000    52.421156     5.026116  121.000000   10.000000
#
# Missing values in each column:
# id                 0
# name               0
# address            0
# category           0
# location           0
# lat                0
# lng                0
# numReviews       887
# reviews          887
# polarity         820
# details            0
# reviews_text       0
# details_text       0
# originalId      1276
# subCategory     1276
# dtype: int64
#
# Sample of reviews for the first accommodation:
# If anybody is searching for a great place to stay in Amsterdam Camillo&#39;s Bed and Breakfast is the perfect place to stay. The location is great, the rooms are super nice, the breakfast is awesome. So is Camillo, thank you for being such a nice host. We had some awesome days in Amsterdam and we will definitely stay at your Bed and Breakfast when we will visit Amsterdam again.
#
# Sample of details for the first accommodation:
# {'id': 223829, 'name': 'Amsterdam Bed and Breakfast CityCenter', 'address': 'Sint Jacobsstraat 21, Amsterdam, Netherlands', 'category': 'accommodation', 'location': 'Amsterdam', 'lat': 52.376568, 'lng': 4.894706, 'services': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None}, 'phone_number': '06 45160078', 'international_phone_number': '+31 6 45160078', 'website': 'http://www.citycenter-amsterdam.com', 'icon': 'http://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png', 'description': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None, 'unidentified': None}, 'external_urls': {'Foursquare': '', 'Facebook': '', 'GooglePlaces': 'https://plus.google.com/108257070561151432423/about?hl=en-US', 'Booking': ''}, 'statistics': {'Foursquare': {'checkinsCount': None, 'usersCount': None, 'tipCount': None, 'price': None, 'likes': None, 'hereNow': {'count': None, 'summary': None, 'groups': []}}, 'Facebook': {'checkins': None, 'talking_about_count': None, 'were_here_count': None, 'fan_count': None}}, 'numReviews': 5, 'reviews': ['533ecc7aae9eef521e5ec9ce', '533ecc7aae9eef521e5ec9cf', '533ecc7aae9eef521e5ec9d0', '533ecc7aae9eef521e5ec9d1', '533ecc7aae9eef521e5ec9d2'], 'polarity': 10}

# %%
# script1.py

import requests
import pandas as pd
from urllib.parse import urlencode
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import sys

# Define the list of locations and categories
LOCATIONS = ["Amsterdam"]
CATEGORIES = ["accommodation", "restaurant", "poi", "attraction"]
#  "Barcelona", "Berlin"
# API Configuration
BASE_URL = "http://tour-pedia.org/api"
GET_PLACES_ENDPOINT = "getPlaces"
GET_REVIEWS_ENDPOINT = "getReviewsByPlaceId"
GET_DETAILS_ENDPOINT = "getPlaceDetails"

# Number of threads (adjust as needed, up to 192)
MAX_WORKERS = 60

def get_data(endpoint, params=None):
    """
    Fetch data from the Tour-Pedia API.

    Args:
        endpoint (str): API endpoint to call.
        params (dict, optional): Query parameters for the API call.

    Returns:
        dict or list: Parsed JSON response from the API, or None if an error occurs.
    """
    url = f"{BASE_URL}/{endpoint}"
    if params:
        url += "?" + urlencode(params)
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        print(f"Success: {url}")
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Request failed for URL: {url}\nError: {e}", file=sys.stderr)
        return None

def process_place(place, category, location):
    """
    Process a single place by fetching its reviews and details.

    Args:
        place (dict): Place data.
        category (str): Category of the place.
        location (str): Location of the place.

    Returns:
        dict: Updated place data with reviews and details.
    """
    place_id = place.get('id')
    place_name = place.get('name', 'N/A')

    # Fetch reviews
    reviews = get_data(GET_REVIEWS_ENDPOINT, {"placeId": place_id})
    if reviews:
        reviews_text = [review.get('text', '') for review in reviews]
    else:
        reviews_text = []

    # Fetch details
    details = get_data(GET_DETAILS_ENDPOINT, {"id": place_id})
    if details:
        details_text = details
    else:
        details_text = {}

    # Be nice to the API
    time.sleep(0.1)  # Reduced sleep to accommodate high concurrency

    return {
        "location": location,
        "category": category,
        "place_id": place_id,
        "place_name": place_name,
        "reviews_text": reviews_text,
        "details_text": details_text
    }

def fetch_data_for_category(location, category):
    """
    Fetch and process data for a specific location and category.

    Args:
        location (str): Location name.
        category (str): Category name.

    Returns:
        list: List of processed place data.
    """
    params = {
        "location": location,
        "category": category
    }
    
    places = get_data(GET_PLACES_ENDPOINT, params)
    
    if not places:
        print(f"Failed to retrieve data for {location} - {category}", file=sys.stderr)
        return []
    
    print(f"Retrieved {len(places)} places for {location} - {category}")
    
    processed_places = []
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [
            executor.submit(process_place, place, category, location)
            for place in places
        ]
        for future in as_completed(futures):
            try:
                result = future.result()
                if result:
                    processed_places.append(result)
            except Exception as e:
                print(f"Error processing a place in {location} - {category}: {e}", file=sys.stderr)
    
    return processed_places

def main():
    """
    Main function to execute data fetching and processing.
    """
    all_data = []
    
    for location in LOCATIONS:
        for category in CATEGORIES:
            data = fetch_data_for_category(location, category)
            all_data.extend(data)
    
    if all_data:
        df = pd.DataFrame(all_data)
        csv_filename = 'amsterdam_barcelona_berlin_data.csv'
        df.to_csv(csv_filename, index=False)
        print(f"\nData saved to '{csv_filename}'")
        
        # Optional: Display DataFrame info and sample
        print("\nDataFrame Info:")
        print(df.info())
        
        print("\nFirst few rows of the DataFrame:")
        print(df.head())
        
        print("\nBasic statistics of numerical columns:")
        print(df.describe())
        
        print("\nMissing values in each column:")
        print(df.isnull().sum())
        
        # Sample of reviews and details
        if not df.empty:
            first_entry = df.iloc[0]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20260 entries, 0 to 20259
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   location      20260 non-null  object
#  1   category      20260 non-null  object
#  2   place_id      20260 non-null  int64
#  3   place_name    20260 non-null  object
#  4   reviews_text  20260 non-null  object
#  5   details_text  20260 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 949.8+ KB
# None
#
# First few rows of the DataFrame:
#     location       category  place_id                              place_name  \
# 0  Amsterdam  accommodation    223896                       Hotel Cornerhouse
# 1  Amsterdam  accommodation    223771                          American Hotel
# 2  Amsterdam  accommodation    223793                                NL Hotel
# 3  Amsterdam  accommodation    223778                         Hotel Amsterdam
# 4  Amsterdam  accommodation    223829  Amsterdam Bed and Breakfast CityCenter
#
#                                         reviews_text  \
# 0                                                 []
# 1  [We went here for the sunday jazz brunch. The ...
# 2                                                 []
# 3                                                 []
# 4  [If anybody is searching for a great place to ...
#
#                                         details_text
# 0  {'id': 223896, 'name': 'Hotel Cornerhouse', 'a...
# 1  {'id': 223771, 'name': 'American Hotel', 'addr...
# 2  {'id': 223793, 'name': 'NL Hotel', 'address': ...
# 3  {'id': 223778, 'name': 'Hotel Amsterdam', 'add...
# 4  {'id': 223829, 'name': 'Amsterdam Bed and Brea...
#
# Basic statistics of numerical columns:
#             place_id
# count   20260.000000
# mean   207337.923149
# std    146679.075172
# min     26152.000000
# 25%     32036.750000
# 50%    257748.500000
# 75%    359516.250000
# max    541473.000000
#
# Missing values in each column:
# location        0
# category        0
# place_id        0
# place_name      0
# reviews_text    0
# details_text    0
# dtype: int64
#
# Sample of reviews for the first entry:
# No reviews available.
#
# Sample of details for the first entry:
# {'id': 223896, 'name': 'Hotel Cornerhouse', 'address': 'Burgwallen-Nieuwe Zijde, Amsterdam, Netherlands', 'category': 'accommodation', 'location': 'Amsterdam', 'lat': 52.37431, 'lng': 4.89145, 'services': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None}, 'phone_number': '020 624 1326', 'international_phone_number': '+31 20 624 1326', 'website': 'http://www.hotelcornerhouse.nl/', 'icon': 'http://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png', 'description': {'en': None, 'it': None, 'fr': None, 'nl': None, 'de': None, 'es': None, 'unidentified': None}, 'external_urls': {'Foursquare': '', 'Facebook': '', 'GooglePlaces': 'https://plus.google.com/101500400979597980327/about?hl=en-US', 'Booking': {'en': 'http://www.booking.com/hotel/nl/cornerhouse.en-gb.html', 'fr': 'http://www.booking.fr/hotel/nl/cornerhouse.fr.html', 'it': 'http://www.booking.it/hotel/nl/cornerhouse.it.html', 'es': 'http://www.booking.es/hotel/nl/cornerhouse.es.html', 'de': 'http://www.booking.de/hotel/nl/cornerhouse.de.html', 'nl': 'http://www.booking.nl/hotel/nl/cornerhouse.nl.html'}}, 'statistics': {'Foursquare': {'checkinsCount': None, 'usersCount': None, 'tipCount': None, 'price': None, 'likes': None, 'hereNow': {'count': None, 'summary': None, 'groups': []}}, 'Facebook': {'checkins': None, 'talking_about_count': None, 'were_here_count': None, 'fan_count': None}}}
